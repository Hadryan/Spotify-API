# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
##read in csv or connect to url

url = 'https://en.wikipedia.org/wiki/List_of_rock_music_performers'
response = requests.get(url)
soup = bs(response.text, 'html.parser')

# %%
stuff = soup.find_all('li')

bands = []
for x in stuff:
    data = x.text.lstrip()
    bands.append(data)

# %%
gt= bands[28:810]
# Out:
# ['10cc',
#  'The 1975',
#  '21 Pilots',
#  '3 Doors Down',
#  '30 Seconds To Mars',
#  '311',
#  '38 Special',
#  '5 Seconds of Summer',
#  '7th Order',
#  '? and the Mysterians',
#  'ABBA',
#  'AC/DC',
#  'Accept https://en.wikipedia.org/wiki/Accept_(band)',
#  'Adam Ant',
#  'Adam Faith',
#  'Adam Lambert',
#  'AJR',
#  'Avenged Sevenfold',
#  'Avril Lavigne',
#  'Adam Levine',
#  'Aerosmith',
#  'A-ha',
#  'Akon',
#  'Albert Lee',
#  'Alex Chilton',
#  'Alabama[1]',
#  'Alan Parsons',
#  'Alice Cooper[2]',
#  'Alice in Chains[3]',
#  "Alice N' Chains[4]",
#  'Alien Ant Farm',
#  'All American Rejects',
#  'Allman Brothers',
#  'Also Eden',
#  'Alter Bridge',
#  'America',
#  'Anarbor',
#  'Andy Gibb',
#  'Angelica Hale',
#  'The Angels (American group)',
#  'Angels & Airwaves',
#  'The Animals',
#  'The Archies',
#  'Arctic Monkeys',
#  'Argent',
#  'Art Garfunkel',
#  'Ashlee Simpson',
#  'Audioslave',
#  'The Avett Brothers',
#  'Awolnation',
#  'Axl Rose',
#  'Ayo & Teo',
#  'Ayub Bachchu',
#  'Bachman Turner Overdrive',
#  'Backstreet Boys',
#  'Bad Company',
#  'Badfinger',
#  'Bad Religion',
#  'The Band',
#  'Band Aid',
#  'The Band Perry',
#  'The Bangles',
#  'Barns Courtney',
#  'Bastille',
#  'Bay City Rollers',
#  'B.B. King',
#  'Ben E. King',
#  'Beck',
#  'Beastie Boys',
#  'The Beatles',
#  'The Beach Boys',
#  'Bee Gees',
#  'Ben Folds',
#  'Ben Folds 5',
#  'Better Than Ezra',
#  'The Big Bopper',
#  'Big & Rich',
#  'Big Time Rush (band)',
#  'Bill Haley & The Comets',
#  'Bill Withers',
#  'Billy Corgan[5]',
#  'Billy Fury',
#  'Billy Idol',
#  'Billy J. Kramer',
#  'Billy Joel',
#  'Billy Preston',
#  'Billy Squier',
#  'Bjork',
#  'The Black Crowes',
#  'Black Flag',
#  'The Black Keys',
#  'Black Label Society',
#  'Black Sabbath',
#  'Bleachers',
#  'Blind Melon[6]',
#  'Blink 182',
#  'Blondie',
#  'Blood Sweat & Tears',
#  'Bloodhound Gang',
#  'Blue Öyster Cult',
#  'Blues Brothers',
#  'Blues Traveller',
#  'Blur',
#  'Bo Diddley',
#  'Bob Dylan[7]',
#  'Bob Marley',
#  'Bob Seger',
#  'Bobby Darin',
#  'Bobby Lewis',
#  'Bobby Vee',
#  "Booker T. and the MG's",
#  'Bowling For Soup',
#  'Bon Jovi[8]',
#  'Boston',
#  'The Box Tops',
#  'Boys Like Girls',
#  'Boyz II Men',
#  'Bread',
#  'Brenda Lee',
#  'Brett Young',
#  'Brian Eno',
#  'Brian May',
#  'Bruce Springsteen',
#  'Bruce & Terry',
#  'Bryan Adams',
#  'Buck Cherry',
#  'Buddy Holly',
#  'Buffalo Springfield',
#  'The Buggles',
#  'Bullet For My Valentine',
#  'Bush',
#  'Butthole Surfers',
#  'Buzzcocks',
#  'The Byrds',
#  'Cake',
#  'Cage the Elephant',
#  'Candlebox',
#  'Canned Heat',
#  'Caravan[9]',
#  'Carl Perkins',
#  'Carly Simon',
#  'Carole King',
#  'The Cars',
#  'The Cardigans',
#  'The Carpenters',
#  'Carrie Underwood',
#  'Catfish and the Bottlemen',
#  'Celine Dion',
#  'The Chainsmokers',
#  'The Chantays',
#  'Charlie Daniels Band',
#  'Cheap Trick',
#  'Cher',
#  'Chevelle',
#  'Chicago',
#  'Chris Cornell',
#  'Chris Stapleton',
#  'Christopher Cross',
#  'Chubby Checker',
#  'Chuck Berry',
#  'Cliff Richard',
#  'The Clash',
#  'The Climax Blues Band',
#  'Coldplay',
#  'Colbie Caillat',
#  'Collective Soul',
#  'Conway Twitty',
#  'Counting Crows',
#  'The Cranberries',
#  'Cream',
#  'Creed',
#  'Creedence Clearwater Revival',
#  'Cromagnon',
#  'Crosby, Stills, Nash & Young',
#  'Crossfade',
#  'The Cult',
#  'Culture Club',
#  'The Cure',
#  'Cypress Hill',
#  'Damn Yankees',
#  'Dan Fogelberg',
#  'Daughtry',
#  'Dave Clark Five',
#  'David Bowie',
#  'Days of the New',
#  'Death Cab for Cutie',
#  'Deborah Harry',
#  'Derek and the Dominos',
#  'Def Leppard',
#  'Deep Purple',
#  'Depeche Mode',
#  'Devo',
#  'Dexys Midnight Runners',
#  'Dick Dale',
#  'Dickie Pride',
#  'Dire Straits',
#  'Disturbed',
#  'Dixie Chicks',
#  'DNCE',
#  'Dolly Parton',
#  'Don Henley',
#  'Donnie Iris',
#  'Donovan',
#  'Doobie Brothers',
#  'Dorsey Burnette',
#  'Dr. Hook and the Medicine Show',
#  'Dream Theater',
#  'Drowning Pool',
#  'Duane Eddy',
#  'Duff McKagan',
#  'Dusty Springfield',
#  'The Doors',
#  'Duran Duran',
#  'E Street Band',
#  'Eagles',
#  'Earth Wind and Fire',
#  'Eddie Bond',
#  'Eddie Cochran',
#  'Eddie Money',
#  'Edgar Winter',
#  'Electric Light Orchestra',
#  'Elton John',
#  'Elvis Presley',
#  'Emerson Lake and Palmer',
#  'Emmylou Harris',
#  'England Dan & John Ford Coley',
#  'En Vogue',
#  'Eric Carmen',
#  'Eric Clapton',
#  'Europe',
#  'Eurythmics',
#  'Evanescence',
#  'Everclear',
#  'The Everly Brothers',
#  'Extreme',
#  'Fabian',
#  'Fabulous Thunderbirds',
#  'Faces',
#  'Fairport Convention',
#  'Faith Evans',
#  'Faith Hill',
#  'Faith No More',
#  'Falco',
#  'The Fall',
#  'Fall Out Boy',
#  'Fastball',
#  'Fatboy Slim',
#  'Fats Domino',
#  'Fergie',
#  'Fifth Harmony',
#  'Filter',
#  'Five For Fighting',
#  'Fleetwood Mac',
#  'Flaming Lips',
#  'Flock of Seagulls',
#  'Flogging Molly',
#  'Flora Cash',
#  'Florence and the Machine',
#  'Flyleaf',
#  'Foals',
#  'Foghat',
#  'Foo Fighters',
#  'Foreigner',
#  'Foster the People',
#  'Fountains of Wayne',
#  'The Four Seasons',
#  'Frank Zappa',
#  'Frankie Goes to Hollywood',
#  'Frankie Valli',
#  'Franz Ferdinand',
#  'The Fray',
#  'Free',
#  'Freddie Mercury',
#  'Fuel',
#  'Fun',
#  'Funkadelic',
#  'Garbage',
#  'Gary Glitter',
#  'Genesis',
#  'Gene Vincent',
#  'Gene Summers',
#  'Gentle Giant',
#  'George Harrison',
#  'George Michael',
#  'George Thorogood',
#  'Georgia Satellites',
#  'Gin Blossoms',
#  'Girls Aloud',
#  'Gnarls Barkley',
#  'Glenn Frey',
#  'Godsmack',
#  'Golden Earring',
#  "The Go Go's",
#  'Goo Goo Dolls',
#  'Good Charlotte',
#  'Gorillaz',
#  'Gotye',
#  'Grand Funk Railroad',
#  'Grateful Dead',
#  'Great White',
#  'Green Day',
#  'Gregg Allman',
#  'Greta Van Fleet',
#  'Guess Who',
#  "Guns N' Roses",
#  'Gym Class Heroes',
#  'Hailee Steinfeld',
#  'Halestorm',
#  'Hall & Oates',
#  'Halsey',
#  'Hanson',
#  'Harry Chapin',
#  'Harry Nillson',
#  'Harry Styles',
#  'Harvey Danger',
#  'Hawkwind',
#  'Heart',
#  "Herman's Hermits",
#  'The Hives',
#  'Hole',
#  'The Hollies',
#  'Hootie & The Blowfish',
#  'House Of Pain',
#  'Huey Lewis & The News',
#  'Human League',
#  'Humble Pie',
#  'Idlewild[10]',
#  'Iggy Pop',
#  'Imagine Dragons',
#  'Incubus',
#  'INXS',
#  'Iron Butterfly',
#  'Iron Maiden',
#  'The Isley Brothers',
#  'Izzy Stradlin',
#  'J. Geils',
#  'J. Geils Band',
#  'Jack Black',
#  'Jack Scott',
#  'Jack White',
#  'Jackie Wilson',
#  'Jackson Browne',
#  'Jackson Five',
#  'Jack & Jack',
#  'Jake Owen',
#  'The Jam',
#  'James Taylor',
#  'Jan & Dean',
#  'Jana Kramer',
#  "Jane's Addiction",
#  'Janet Jackson',
#  'Jeff Beck',
#  'Jeff Beck Group',
#  'Jeff Buckley',
#  'Jefferson Airplane',
#  'Jefferson Starship',
#  'Jerry Garcia',
#  'Jerry Lee Lewis',
#  'Jethro Tull',
#  'Jimmy Buffett',
#  'Jimmy Eat World',
#  'Jimi Hendrix',
#  'Jimi Hendrix Experience',
#  'Jimmy Page',
#  'Joan Baez',
#  'Joan Jett',
#  'Joe Cocker',
#  'Joe Walsh',
#  'Jon Bon Jovi',
#  'John Deacon',
#  'John Denver',
#  'John Fogerty',
#  'John Lennon',
#  'John Mayer',
#  'John Mayall',
#  'John Mayall & the Bluesbreakers',
#  'Johnny Burnette',
#  'Johnny Cash',
#  'Johnny Thunders',
#  'Johnny Winter[11]',
#  'Jojo Siwa',
#  'Jonas Brothers',
#  'Joni Mitchell',
#  'Journey',
#  'Joy Division',
#  'Judas Priest',
#  'Julian Lennon',
#  'Justin Bieber',
#  'Justin Timberlake',
#  'Kaiser Chiefs',
#  'Kaleo',
#  'Kansas',
#  'Kanye West',
#  'Kenny Loggins',
#  'Kenny Rogers',
#  'The Knack',
#  'Kid Rock',
#  'The Killers',
#  'Kim Carnes',
#  'Kings Of Leon',
#  'The Kingsmen',
#  'The Kinks',
#  'Kiss',
#  'Korn',
#  'Kris Kristofferson',
#  'L7',
#  'Lady Antebellum',
#  'Lady Gaga',
#  'Laura Nyro',
#  'Lauren Daigle',
#  'Led Zeppelin',
#  'Lenny Kravitz',
#  'Liam Payne',
#  'Lifehouse',
#  'Limp Bizkit',
#  'Linda Ronstadt',
#  'Lindisfarne[12]',
#  'Lindsay Lohan',
#  'Link Wray',
#  'Linkin Park',
#  'Lita Ford',
#  'Little Big Town',
#  'Little Feat',
#  'Little Richard',
#  'Living Colour',
#  'Lizzo',
#  'Lizzy Hale',
#  'Loggins & Messina',
#  'Lonestar',
#  'Looking Glass',
#  'Loretta Lynn',
#  'Lou Reed',
#  'Louis Tomlinson',
#  'Loverboy',
#  'LRB',
#  "The Lovin' Spoonful",
#  'Lucy Hale',
#  'Ludacris',
#  'The Lumineers',
#  'Lush',
#  'Lynyrd Skynyrd[13]',
#  'Mad Season[14]',
#  'Manfred Mann',
#  'Manic Street Preachers[15]',
#  'Maren Morris',
#  'Marian Hill',
#  'Marianne Faithfull',
#  'Maroon 5',
#  'The Marshall Tucker Band',
#  'Marty Wilde',
#  'The Marvellettes',
#  'Marilyn Manson',
#  'Matchbox Twenty',
#  'Meatloaf',
#  'Megadeth',
#  'Melvins[16]',
#  'Mercyme',
#  'Metallica',
#  'Men at Work',
#  'MC5',
#  'Michael Jackson',
#  'Migos',
#  'Mighty Mighty Bosstones',
#  'Mike and the Mechanics',
#  'Mike Posner',
#  'Mike Sanchez',
#  'Miranda Lambert',
#  'The Monkees',
#  'Montgomery Gentry',
#  'Montrose',
#  'The Moody Blues',
#  'The Mothers of Invention',
#  'Mötley Crüe',
#  'Motörhead',
#  'Mott The Hoople',
#  'Mountain',
#  'Mudhoney',
#  'Mumford & Sons',
#  'Muse',
#  'My Chemical Romance',
#  'Nancy Sinatra',
#  'Natalie Cole',
#  'Nathaniel Rateliff',
#  'Nazareth',
#  'N.E.R.D',
#  'New Riders of the Purple Sage',
#  'New Order',
#  'Newsboys',
#  'Ne-Yo',
#  'Niall Horan',
#  'Nickelback',
#  'Night Ranger',
#  'Nine Inch Nails',
#  'Nirvana',
#  'Nitty Gritty Dirt Band',
#  'No Doubt',
#  'Norah Jones',
#  'Norman Greenbaum',
#  'The Notorious B.I.G',
#  'Oasis',
#  'Of Monsters And Men',
#  'The Offspring',
#  'One Direction',
#  'Orgy',
#  'Os Mutantes',
#  'The Osmonds',
#  'Otis Redding',
#  'The Outfield',
#  'Outlaws',
#  'Outkast',
#  'Ozark Mountain Daredevils',
#  'Ozzy Osbourne',
#  'Pantera',
#  'Paramore',
#  'Parliament',
#  'Parliament-Funkadelic',
#  'Pat Benatar',
#  'Patsy Cline',
#  'Patti Smith',
#  'Paul McCartney',
#  'Paul Revere & the Raiders',
#  'Paul Simon',
#  'Paul Weller[17]',
#  'Paula Cole',
#  'Pearl Jam',
#  'Peggy Sue',
#  'Pete Townshend',
#  'Peter and Gordon',
#  'Peter Frampton',
#  'Peter Gabriel',
#  'Phil Collins',
#  'Philip Bailey',
#  'The Picks',
#  'Pink',
#  'Pink Floyd',
#  'Pixies',
#  'Plastic Ono Band',
#  'Poco',
#  'Poison',
#  'The Police',
#  'Porno for Pyros',
#  'Portugal. The Man',
#  'Powerman 5000',
#  'The Presidents of the United States of America',
#  'The Pretenders',
#  'The Pretty Things',
#  'Primal Scream[18][19]',
#  'The Proclaimers[20]',
#  'The Prodigy',
#  'Prince',
#  'Procol Harum',
#  'Puddle Of Mudd',
#  'Pure Prairie League',
#  'Q5',
#  'Queen',
#  'Queen Latifah',
#  'Queens Of The Stone Age',
#  'Queensrÿche',
#  'The Quarrymen',
#  'Quiet Riot',
#  'Radiohead',
#  'Rage Against The Machine',
#  "Rag'n'Bone Man",
#  'Rainbow',
#  'Ram Jam',
#  'The Ramones',
#  'Rammstein',
#  'The Rascals',
#  'Rascal Flatts',
#  'The Rasmus',
#  'The Raspberries',
#  'Ray Charles',
#  'Redbone',
#  'Red Hot Chili Peppers',
#  'Red Rider',
#  'R.E.M[21]',
#  'R.E.O Speedwagon',
#  'The Replacements',
#  'Richard Hell',
#  'Rick James',
#  'Ricky Nelson',
#  'Ringo Starr',
#  "Ringo Starr's All-Starr Band",
#  'Rise Against',
#  'Ritchie Valens',
#  'Rob Thomas',
#  'Rob Zombie',
#  'Robbie Williams',
#  'Robert Palmer',
#  'Robert Plant',
#  'Rod Stewart',
#  'Roger Daltrey',
#  'Roger Taylor',
#  'The Rolling Stones',
#  'The Ronettes',
#  'Ronnie James Dio',
#  'Ronny & the Daytonas',
#  'Rory Storm',
#  'Roxette',
#  'Roxy Music',
#  'Roy Orbison',
#  'Run DMC',
#  'Rush',
#  'Samantha Fox',
#  'Sammy Hagar',
#  'Santana',
#  'Sara Bareilles',
#  'Savage Garden',
#  'Scream[22][23]',
#  "Screamin' Jay Hawkins",
#  'Screaming Trees',
#  'Scorpions',
#  'Seals & Croft',
#  'Sean Kingston',
#  'Sean Lennon',
#  'Sean Paul',
#  'Semisonic',
#  'Sex Pistols',
#  'Shaed',
#  'Shakin Stevens',
#  'Shania Twain',
#  'The Shirelles',
#  'Shinedown',
#  'Slash',
#  'Silver Bullet Band',
#  'Silversun Pickups',
#  'Simon & Garfunkel',
#  'Simple Plan',
#  'Siouxsie and the Banshees',
#  'Sir Mix-a-Lot',
#  'Sir Sly',
#  'Skid Row',
#  'Skillet',
#  'Skillrex',
#  'Slade[24]',
#  'Slipknot',
#  'Sleater-Kinney',
#  'Sly & The Family Stone',
#  'Smash Mouth',
#  'The Smashing Pumpkins',
#  'The Smiths',
#  'Smokey Robinson',
#  'Smokie',
#  'Social Distortion',
#  'Sonic Youth',
#  'Sonny Bono',
#  'Sonny & Cher',
#  'Soundgarden',
#  'Spandau Ballet',
#  '[Sparks]',
#  'Spencer Davis Group',
#  'Sponge',
#  'Squeeze[25]',
#  'Staind',
#  'Starship',
#  'Status Quo',
#  'Steely Dan',
#  'Steppenwolf',
#  'Steve Miller Band',
#  'Steve Winwood',
#  'Steven Adler',
#  'Sting',
#  'Stone Temple Pilots',
#  'Stone the Crows',
#  'The Stooges',
#  'Stray Cats',
#  'Styx',
#  'Sublime',
#  'Sublime With Rome',
#  'Sugarhill Gang',
#  'Sugarland',
#  'Sugar Ray',
#  'Sum 41',
#  'Sun Damage',
#  'Sunny Day Real Estate',
#  'Supercar Supertramp',
#  'The Supremes',
#  'The Surfaris',
#  'Sweet',
#  'Switchfoot',
#  'Syd Barrett',
#  'System Of A Down',
#  'T. Rex',
#  'Take That',
#  'Talking Heads',
#  'Talk Talk',
#  'Tangerine Dream',
#  'Tantric',
#  'Taylor Swift',
#  'Tears For Fears',
#  'Ted Nugent[26]',
#  'Temple Of The Dog',
#  'Temptations',
#  'Ten Years After',
#  'Tenacious D',
#  'Terry Knight and the Pack',
#  'Tesla',
#  'Them',
#  'Them Crooked Vultures',
#  'Theory Of A Deadman',
#  'Thompson Twins',
#  'Three Dog Night',
#  'Three Days Grace',
#  'Thin Lizzy',
#  'Third Eye Blind',
#  'Tina Turner',
#  'Toadies',
#  'Toby Keith',
#  'Tokio Hotel',
#  'Tom Cochrane',
#  'Tom Petty',
#  'Tom Petty and the Heartbreakers',
#  'Tom Robinson Band[27]',
#  'Tommy & The Tom Toms',
#  'Tommy James & the Shondells',
#  'Tonic',
#  'Tori Kelly',
#  'Toto',
#  'Tommy Tutone',
#  'Tove Lo',
#  'Trace Adkins',
#  'Traffic',
#  'Train',
#  'Traveling Wilburys',
#  'Travis',
#  'Travis Tritt',
#  'Travie McCoy',
#  'Troggs',
#  'Tupac',
#  'The Turtles',
#  'Twisted Sister',
#  'U2',
#  'UB40',
#  'UFO[28]',
#  'Uncle Kracker',
#  'Uriah Heep',
#  'USA for Africa',
#  'Vampire Weekend',
#  'Van Halen',
#  'Van Morrison',
#  'Van Zant',
#  'Velvet Underground',
#  'Vertical Horizon',
#  'The Verve',
#  'The Verve Pipe',
#  'Vince Taylor',
#  'Vordan Karmir',
#  'Wanda Jackson',
#  'War',
#  'Warren Smith',
#  'Warren Zevon',
#  'Waylon Jennings',
#  'We The Kings',
#  'Weezer',
#  'Weird Al Yankovic',
#  'Whitesnake',
#  'The Wanted',
#  'The Weeknd',
#  'The White Stripes',
#  'White Zombie',
#  'The Who',
#  "Why Don't We",
#  'The Wiggles',
#  'Wilbert Harrison',
#  'Willie Nelson',
#  'Wings',
#  'Wolfmother',
#  'X',
#  'X Ambassadors',
#  'XXXTentacion',
#  'The Yardbirds',
#  'Yes',
#  'Young the Giant',
#  'The Youngbloods',
#  'Zac Brown Band',
#  'Zakk Wylde',
#  'Zayn Malik',
#  'Zebra (American band)[29]',
#  'Zebra (Yugoslav band)',
#  'Zedd',
#  'The Zombies',
#  'ZZ Top']

# %%
###set up API

from __future__ import print_function
#Import things and whatnot.
import spotipy
from spotipy import Spotify
import requests
import json
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import oauth2

SPOTIFY_CLIENT_ID = '97d0cf2236334807b1eb85e357156547'
SPOTIFY_CLIENT_SECRET = '5daeca4781fb4ac98408b5ce82a01ff6'


SPOTIPY_REDIRECT_URI = 'http://localhost:8080'
SCOPE = 'user-library-read'
CACHE = '.spotipyoauthcache'

# %%
### Set up API part 2

#DONT TOUCH THIS ITS FROM SPOTIPY PROS NOT ME 
#https://github.com/plamere/spotipy/blob/51637d7b2c3f7ebcf12b94fd22d6fb21048949bc/spotipy/oauth2.py


__all__ = [
    'is_token_expired',
    'SpotifyClientCredentials',
    'SpotifyOAuth',
    'SpotifyOauthError'
]

import base64
import json
import os
import sys
import time

import requests

# Workaround to support both python 2 & 3
import six
import six.moves.urllib.parse as urllibparse


class SpotifyOauthError(Exception):
    pass


def _make_authorization_headers(client_id, client_secret):
    auth_header = base64.b64encode(
        six.text_type(
            client_id +
            ':' +
            client_secret).encode('ascii'))
    return {'Authorization': 'Basic %s' % auth_header.decode('ascii')}


def is_token_expired(token_info):
    now = int(time.time())
    return token_info['expires_at'] - now < 60

sp_oauth = oauth2.SpotifyOAuth(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET, SPOTIPY_REDIRECT_URI,scope=SCOPE,cache_path=CACHE )

class SpotifyClientCredentials(object):
    OAUTH_TOKEN_URL = 'https://accounts.spotify.com/api/token'

    def __init__(self, client_id=None, client_secret=None, proxies=None):
        """
        You can either provide a client_id and client_secret to the
        constructor or set SPOTIPY_CLIENT_ID and SPOTIPY_CLIENT_SECRET
        environment variables
        """
        if not client_id:
            client_id = SPOTIFY_CLIENT_ID

        if not client_secret:
            client_secret = SPOTIFY_CLIENT_SECRET

        if not client_id:
            raise SpotifyOauthError('No client id')

        if not client_secret:
            raise SpotifyOauthError('No client secret')

        self.client_id = client_id
        self.client_secret = client_secret
        self.token_info = None
        self.proxies = proxies

    def get_access_token(self):
        """
        If a valid access token is in memory, returns it
        Else feches a new token and returns it
        """
        if self.token_info and not self.is_token_expired(self.token_info):
            return self.token_info['access_token']

        token_info = self._request_access_token()
        token_info = self._add_custom_values_to_token_info(token_info)
        self.token_info = token_info
        return self.token_info['access_token']

    def _request_access_token(self):
        """Gets client credentials access token """
        payload = {'grant_type': 'client_credentials'}

        headers = _make_authorization_headers(
            self.client_id, self.client_secret)

        response = requests.post(self.OAUTH_TOKEN_URL, data=payload,
                                 headers=headers, verify=True,
                                 proxies=self.proxies)
        if response.status_code != 200:
            raise SpotifyOauthError(response.reason)
        token_info = response.json()
        return token_info

    def is_token_expired(self, token_info):
        return is_token_expired(token_info)

    def _add_custom_values_to_token_info(self, token_info):
        """
        Store some values that aren't directly provided by a Web API
        response.
        """
        token_info['expires_at'] = int(time.time()) + token_info['expires_in']
        return token_info
    
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
artist_ids=[]
not_found=[]
record = 0
for artist in gt:
    try:
        artist_search = sp.search(q=artist, type='artist', limit=1)
        artist_id = artist_search['artists']['items'][0]['id']
        artist_ids.append(artist_id)
        for_log = artist_id
        record= record + 1
#         print(f"Processing Record {record}| {for_log}")
    except:
        not_found.append(record)
        print(f" id not found {record}")
# Out:
#  id not found 12
#  id not found 26
#  id not found 26
#  id not found 26
#  id not found 35
#  id not found 72
#  id not found 74
#  id not found 87
#  id not found 96
#  id not found 103
#  id not found 128
#  id not found 151
# retrying ...1secs
#  id not found 314
#  id not found 366
#  id not found 402
#  id not found 425
#  id not found 425
#  id not found 426
#  id not found 437
# retrying ...1secs
#  id not found 503
#  id not found 526
#  id not found 526
#  id not found 553
#  id not found 553
# retrying ...2secs
#  id not found 558
#  id not found 583
#  id not found 608
#  id not found 625
#  id not found 645
#  id not found 646
#  id not found 660
#  id not found 681
#  id not found 681
#  id not found 700
#  id not found 702
#  id not found 742
#  id not found 742

# %%
len(artist_ids)
# Out:
# 745

# %%
len(not_found)
# Out:
# 37

# %%
# Make calls with API to extract song information
####Warning, if you run this twice, it will append to the empty variables twice

track_id1 = []
artist_name1=[]
album1=[]
track_name1=[]
track_album_seq1=[]
release1 = []
record = 0
not_found3 = []
for x in artist_ids:
   try:
        artist_info1 = sp.artist_top_tracks(artist_id=x)
        r = artist_info1["tracks"][0]['id']
        s = artist_info1['tracks'][0]['album']['name']
        t = artist_info1['tracks'][0]['name']
        v = artist_info1['tracks'][0]['track_number']
        w = artist_info1['tracks'][0]['artists'][0]['name']
        y = artist_info1['tracks'][0]['album']['release_date']
        album1.append(s)
        track_name1.append(t)
        track_album_seq1.append(v)
        artist_name1.append(w)
        track_id1.append(r)
        release1.append(y)
        for_log = y
        record= record + 1
        print(f"Processing Record {record}| {for_log}")
   except:
        not_found3.append(record)
        print(f"not found {record}")
# Out:
# Processing Record 1| 1975
# Processing Record 2| 2020-01-16
# Processing Record 3| 2015-05-15
# Processing Record 4| 2000
# Processing Record 5| 2005-01-01
# Processing Record 6| 2001-06-19
# Processing Record 7| 1982-01-01
# Processing Record 8| 2018-06-15
# Processing Record 9| 2015-06-01
# Processing Record 10| 1966
# Processing Record 11| 1976
# Processing Record 12| 1979-07-27
# Processing Record 13| 1982
# Processing Record 14| 2003-12-08
# Processing Record 15| 2009-11-20
# Processing Record 16| 2018-09-21
# Processing Record 17| 2013-08-23
# Processing Record 18| 2002-06-04
# Processing Record 19| 2014-06-23
# Processing Record 20| 1973-01-05
# Processing Record 21| 1985-06-01
# Processing Record 22| 2006-01-01
# Processing Record 23| 2003
# Processing Record 24| 2005
# Processing Record 25| 2012-11-25
# Processing Record 26| 1975
# Processing Record 27| 2001-01-01
# Processing Record 28| 2008-01-01
# Processing Record 29| 1989-06-20
# Processing Record 30| 2011-01-23
# Processing Record 31| 2004-08-10
# Processing Record 32| 1972
# Processing Record 33| 2013-06-04
# Processing Record 689| 2010-12-01
# Processing Record 690| 1988-10-18
# Processing Record 691| 2019-10-04
# Processing Record 692| 2000-10-01
# Processing Record 693| 2010-06-07
# Processing Record 694| 1966-07-25
# Processing Record 695| 1996-02-13
# Processing Record 696| 1967-04
# Processing Record 697| 1984
# Processing Record 698| 1987-03-03
# Processing Record 699| 2000
# Processing Record 700| 2000-06-13
# Processing Record 701| 2009-10-02
# Processing Record 702| 2019-05-03
# Processing Record 703| 1984-01-04
# Processing Record 704| 1967-09
# Processing Record 705| 2005-05-10
# Processing Record 706| 1969
# Processing Record 707| 1999-06-14
# Processing Record 708| 1997-09-29
# Processing Record 709| 1996-03-25
# Processing Record 710| 2013-01-15
# Processing Record 711| 2017-09-20
# Processing Record 712| 2002-01-01
# Processing Record 713| 1994-06-07
# Processing Record 714| 2010-07-01
# Processing Record 715| 1978-06-01
# Processing Record 716| 1985-05-01
# Processing Record 717| 2013-01-01
# Processing Record 718| 2001-05-15
# Processing Record 719| 2006-09-26
# Processing Record 720| 1987-04-07
# Processing Record 721| 2012-01-01
# Processing Record 722| 2019-11-29
# Processing Record 723| 2003-04-01
# Processing Record 724| 1992-01-01
# Processing Record 725| 1971-08-14
# Processing Record 726| 2019-01-17
# Processing Record 727| 2013-01-31
# Processing Record 728| 1959
# Processing Record 729| 1985-05-01
# Processing Record 730| 1973-12-05
# Processing Record 731| 2006-01-01
# Processing Record 732| 2018-03-16
# Processing Record 733| 2015-06-30
# Processing Record 734| 2018-03-16
# Processing Record 735| 2002-05-08
# Processing Record 736| 1983-06-01
# Processing Record 737| 2011
# Processing Record 738| 1967-03-10
# Processing Record 739| 2008-11-17
# Processing Record 740| 2019-09-13
# Processing Record 741| 2019-12-27
# Processing Record 742| 2018-01-23
# Processing Record 743| 1968-04-19
# Processing Record 744| 1973-07-26

# %%
print(len(not_found3))
print(len(release1))
print(len(track_id1))
# Out:
# 1
# 744
# 744

# %%
Rock_Artist_Rank = pd.DataFrame({"track_id":track_id1,
                                    "artist" :artist_name1,
                                    "album": album1,
                                    "track" : track_name1,
                                    "album_track_seq" :track_album_seq1,
                                    "track_release_date" : release1
                                  })
Rock_Artist_Rank
# Out:
#                    track_id                  artist  \
# 0    5HQEmiV2lKnSO6qa2fsR7x                    10cc
# 1    4AQzk2yNWKs6sYhZi6NzVN                The 1975
# 2    3CRDbSIZ4r5MsZ0YwxuEkn       Twenty One Pilots
# 3    6ZOBP3NvffbU4SZcrnt1k6            3 Doors Down
# 4    0lP4HYLmvowOKdsQ7CVkuq  Thirty Seconds To Mars
# ..                      ...                     ...
# 739  3X0773BLlMv6RMq0wkZZAk                 HIXTAPE
# 740  2ez6qvOTHKeI3ss80NGqnI                   SHAED
# 741  09IStsImFySgyp0pIQdqAc                    Zedd
# 742  5AJrhrwz4oSZX2PwwV4qrN             The Zombies
# 743  70YvYr2hGlS01bKRIho1HM                  ZZ Top
#
#                                      album  \
# 0                  The Original Soundtrack
# 1                   Me & You Together Song
# 2                               Blurryface
# 3                          The Better Life
# 4                          A Beautiful Lie
# ..                                     ...
# 739                        HIXTAPE: Vol. 1
# 740                          Melt (Deluxe)
# 741                             The Middle
# 742                     Odessey And Oracle
# 743  Tres Hombres (Expanded 2006 Remaster)
#
#                                                  track  album_track_seq  \
# 0                                      I'm Not In Love                2
# 1                               Me & You Together Song                1
# 2                                         Stressed Out                2
# 3                                           Kryptonite                1
# 4                                             The Kill                3
# ..                                                 ...              ...
# 739  Turn You Down (HARDY feat. Morgan Wallen, Zakk...                9
# 740                             Trampoline (with ZAYN)               15
# 741                                         The Middle                1
# 742                  Time Of The Season (Mono Version)               12
# 743                          La Grange - 2005 Remaster                8
#
#     track_release_date
# 0                 1975
# 1           2020-01-16
# 2           2015-05-15
# 3                 2000
# 4           2005-01-01
# ..                 ...
# 739         2019-09-13
# 740         2019-12-27
# 741         2018-01-23
# 742         1968-04-19
# 743         1973-07-26
#
# [744 rows x 6 columns]

# %%
Rock_Artist_Rank.to_csv("Rock_seq_3.csv", index=False)

# %%
###create empty lists, fill them with API call for audio features

track_id8 = []
dance8 = []
energy8 = []
key8 = []
loudness8 = []
mode8 = []
speechiness8 = []
acousticness8 = []
instrumentalness8 = []
liveness8 = []
valence8 = []
tempo8 = []
duration_ms8 = []
time_signature8 = []
record = 0
not_in2=[]
for features in track_id1 :
   try:
        audio_analysis = sp.audio_features(features)
        track_id8.append(audio_analysis[0]['id'])
        dance8.append(audio_analysis[0]['danceability'])
        energy8.append(audio_analysis[0]['energy'])
        key8.append(audio_analysis[0]['key'])
        loudness8.append(audio_analysis[0]['loudness'])
        mode8.append(audio_analysis[0]['mode'])
        speechiness8.append(audio_analysis[0]['speechiness'])
        acousticness8.append(audio_analysis[0]['acousticness'])
        instrumentalness8.append(audio_analysis[0]['instrumentalness'])
        liveness8.append(audio_analysis[0]['liveness'])
        valence8.append(audio_analysis[0]['valence'])
        tempo8.append(audio_analysis[0]['tempo'])
        duration_ms8.append(audio_analysis[0]['duration_ms'])
        time_signature8.append(audio_analysis[0]['time_signature']) 
        record= record + 1
        print(f"Processing Record {record}")
        
   except:
       not_in2.append(record)
       print(f"not found {record}")
# Out:
# Processing Record 1
# Processing Record 2
# Processing Record 3
# Processing Record 4
# Processing Record 5
# Processing Record 6
# Processing Record 7
# Processing Record 8
# Processing Record 9
# Processing Record 10
# Processing Record 11
# Processing Record 12
# Processing Record 13
# Processing Record 14
# Processing Record 15
# Processing Record 16
# Processing Record 17
# Processing Record 18
# Processing Record 19
# Processing Record 20
# Processing Record 21
# Processing Record 22
# Processing Record 23
# Processing Record 24
# Processing Record 25
# Processing Record 26
# Processing Record 27
# Processing Record 28
# Processing Record 29
# Processing Record 30
# Processing Record 31
# Processing Record 32
# Processing Record 33
# Processing Record 34
# Processing Record 35
# Processing Record 36
# Processing Record 37
# Processing Record 38
# Processing Record 39
# Processing Record 40
# Processing Record 41
# Processing Record 42
# Processing Record 43
# Processing Record 44
# Processing Record 45
# Processing Record 46
# Processing Record 47
# Processing Record 48
# Processing Record 49
# Processing Record 724
# Processing Record 725
# Processing Record 726
# Processing Record 727
# Processing Record 728
# Processing Record 729
# Processing Record 730
# Processing Record 731
# Processing Record 732
# Processing Record 733
# Processing Record 734
# Processing Record 735
# Processing Record 736
# Processing Record 737
# Processing Record 738
# Processing Record 739
# Processing Record 740
# Processing Record 741
# Processing Record 742
# Processing Record 743
# Processing Record 744

# %%
####create dataframe for audio features

features = pd.DataFrame({'track_id' : track_id8,
                                     'danceability': dance8,
                                     'energy': energy8,
                                     'key': key8,
                                     'loudness': loudness8,
                                     'mode' : mode8,
                                     'speechiness' : speechiness8,
                                     'acousticness' : acousticness8,
                                     'instrumentalness': instrumentalness8,
                                     'liveness': liveness8,
                                     'valence': valence8,
                                     'tempo':tempo8,
                                     'duration_ms': duration_ms8,
                                     'time_signature': time_signature8}
                                    )
features
# Out:
#                    track_id  danceability  energy  key  loudness  mode  \
# 0    5HQEmiV2lKnSO6qa2fsR7x         0.404   0.523    4   -15.700     1
# 1    4AQzk2yNWKs6sYhZi6NzVN         0.272   0.763    9    -5.861     1
# 2    3CRDbSIZ4r5MsZ0YwxuEkn         0.734   0.637    4    -5.677     0
# 3    6ZOBP3NvffbU4SZcrnt1k6         0.545   0.865   11    -5.708     0
# 4    0lP4HYLmvowOKdsQ7CVkuq         0.309   0.912    4    -3.881     0
# ..                      ...           ...     ...  ...       ...   ...
# 739  3X0773BLlMv6RMq0wkZZAk         0.615   0.874   11    -3.375     1
# 740  2ez6qvOTHKeI3ss80NGqnI         0.619   0.459    7    -5.782     0
# 741  09IStsImFySgyp0pIQdqAc         0.753   0.657    7    -3.061     1
# 742  5AJrhrwz4oSZX2PwwV4qrN         0.537   0.700    4    -6.852     0
# 743  70YvYr2hGlS01bKRIho1HM         0.545   0.640    4    -9.937     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0575      0.685000          0.000498    0.2820    0.164  133.738
# 1         0.0348      0.000002          0.001570    0.2990    0.394  107.388
# 2         0.1410      0.046200          0.000023    0.0602    0.648  169.977
# 3         0.0286      0.006640          0.000011    0.1680    0.543   99.010
# 4         0.0646      0.001400          0.000271    0.5820    0.302  183.035
# ..           ...           ...               ...       ...      ...      ...
# 739       0.1040      0.013100          0.000000    0.3300    0.604  107.970
# 740       0.0334      0.560000          0.000000    0.1370    0.498  126.803
# 741       0.0449      0.171000          0.000000    0.1120    0.437  107.010
# 742       0.0366      0.142000          0.000002    0.3830    0.695  117.111
# 743       0.2240      0.002490          0.030400    0.1960    0.606   80.544
#
#      duration_ms  time_signature
# 0         366640               4
# 1         209501               4
# 2         202333               4
# 3         233933               4
# 4         231533               3
# ..           ...             ...
# 739       154960               4
# 740       184280               4
# 741       184732               4
# 742       214027               4
# 743       230480               4
#
# [744 rows x 14 columns]

# %%
###combine dataframes
rock_hits_sequence_and_year = pd.merge(Rock_Artist_Rank,features, on = "track_id")

###delete duplicate rows
no_dupes = rock_hits_sequence_and_year.drop_duplicates('track_id', keep = 'first')


# save dataframe
no_dupes.to_csv("rock_seq_and_release_year.csv", index=False)
